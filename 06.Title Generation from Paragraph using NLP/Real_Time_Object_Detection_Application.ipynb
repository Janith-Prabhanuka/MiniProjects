# %%
import urllib.request #Handling URL

from bs4 import BeautifulSoup #Handling or parsing html files

import nltk #toolkit
nltk.download('stopwords') #or is was extracted

from nltk.corpus import stopwords


#get the info from website
response =  urllib.request.urlopen('https://en.wikipedia.org/wiki/Tesla')
html = response.read()


soup = BeautifulSoup(html,'html5lib')
text = soup.get_text(strip = True)

tokens = [t for t in text.split()]


sr= stopwords.words('english')
clean_tokens = tokens[:]
for token in tokens:
    if token in stopwords.words('english'):

        clean_tokens.remove(token)

freq = nltk.FreqDist(clean_tokens)
for key,val in freq.items():
    print(str(key) + ':' + str(val))
freq.plot(20, cumulative=False)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Tesla:6
# -:1
# Wikipedia(function(){var:1
# className="client-js:1
# vector-feature-language-in-header-enabled:1
# vector-feature-language-in-main-page-header-disabled:1
# vector-feature-sticky-header-disabled:1
# vector-feature-page-tools-pinned-disabled:1
# vector-feature-toc-pinned-clientpref-1:1
# vector-feature-main-menu-pinned-disabled:1
# vector-feature-limited-width-clientpref-1:1
# vector-feature-limited-width-content-enabled:1
# vector-feature-custom-font-size-clientpref-1:1
# vector-feature-appearance-enabled:1
# vector-feature-appearance-pinned-clientpref-1:1
# vector-feature-night-mode-enabled:1
# skin-theme-clientpref-day:1
# vector-toc-available";var:1
# cookie=document.cookie.match(/(?:^|;:1
# )enwikimwclientpreferences=([^;]+)/);if(cookie){cookie[1].split('%2C').forEach(function(pref){className=className.replace(new:1
# RegExp('(^|:1
# )'+pref.replace(/-clientpref-\w+$|[^\w-]+/g,'')+'-clientpref-\\w+(:1
# |$)'),'$1'+pref+'$2');});}document.documentElement.className=className;}());RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":[:1
# "",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"75b33ea0-63fc-40ca-bbee-d88c4ecbac8c","wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Tesla","wgTitle":"Tesla","wgCurRevisionId":1241406863,"wgRevisionId":1241406863,"wgArticleId":2029013,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Short:1
# description:2
# different:2
# Wikidata","All:1
# article:2
# disambiguation:7
# pages","All:1
# pages","Disambiguation:2
# pages:4
# surname-holder:2
# lists","Place:1
# name:2
# pages"],"wgPageViewLanguage":"en","wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Tesla","wgRelevantArticleId":2029013,"wgIsProbablyEditable":true,"wgRelevantPageIsProbablyEditable":true,"wgRestrictionEdit":[],:1
# "wgRestrictionMove":[],"wgNoticeProject":"wikipedia","wgCiteReferencePreviewsActive":false,"wgFlaggedRevsParams":{"tags":{"status":{"levels":1}}},"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":6,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":true,"watchlist":true,"tagline":false,"nearby":true},"wgWMESchemaEditAttemptStepOversample":false,"wgWMEPageLength":2000,"wgULSCurrentAutonym":"English","wgRelatedArticlesCompat":[],"wgCentralAuthMobileDomain":false,"wgEditSubmitButtonLabelPublish":true,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":false,"wgVector2022LanguageInHeader":true,"wgULSisLanguageSelectorEmpty":false,"wgWikibaseItemId":"Q765530","wgCheckUserClientHintsHeadersJsApi":["architecture","bitness","brands","fullVersionList","mobile","model","platform","platformVersion"],"GEHomepageSuggestedEditsEnableTopics":true,"wgGETopicsMatchModeEnabled":1
# :false,"wgGEStructuredTaskRejectionReasonTextInputEnabled":false,"wgGELevelingUpEnabledForUser":false};RLSTATE={"ext.globalCssJs.user.styles":"ready","site.styles":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","skins.vector.search.codex.styles":"ready","skins.vector.styles":"ready","skins.vector.icons":"ready","ext.wikimediamessages.styles":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","wikibase.client.init":"ready","ext.wikimediaBadges":"ready"};RLPAGEMODULES=["site","mediawiki.page.ready","mediawiki.toc","skins.vector.js","ext.centralNotice.geoIP","ext.centralNotice.startUp","ext.gadget.ReferenceTooltips","ext.gadget.switcher","ext.urlShortener.toolbar","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.echo.centralauth","ext.eventLogging","ext.wikimediaEvents",:1
# "ext.navigationTiming","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.cx.uls.quick.actions","wikibase.client.vector-2022","ext.checkUser.clientHints","ext.growthExperiments.SuggestedEditSession","wikibase.sidebar.tracking"];(RLQ=window.RLQ||[]).push(function(){mw.loader.impl(function(){return["user.options@12s5i",function($,jQuery,require,module){mw.user.tokens.set({"patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});:1
# }];});});Jump:1
# contentMain:1
# menuMain:1
# menumove:1
# sidebarhideNavigationMain:1
# pageContentsCurrent:1
# eventsRandom:1
# articleAbout:1
# WikipediaContact:1
# usDonateContributeHelpLearn:1
# editCommunity:1
# portalRecent:1
# changesUpload:2
# fileSearchSearchAppearanceCreate:1
# accountLog:2
# inPersonal:1
# toolsCreate:1
# inPages:1
# logged:1
# editorslearn:1
# moreContributionsTalkContentsmove:1
# sidebarhide(Top)1Companies:1
# organizations2Media:1
# entertainment3PlacesToggle:1
# Places:1
# subsection3.1Space4Science:1
# technology5See:1
# alsoToggle:1
# table:1
# contentsTesla51:1
# languagesالعربيةAzərbaycancaবাংলা閩南語:1
# /:3
# Bân-lâm-gúБеларускаяБеларуская:1
# (тарашкевіца)БългарскиBosanskiCatalàČeštinaDanskDeutschEestiΕλληνικάEspañolEuskaraفارسیFrançaisGalego한국어HrvatskiInterlingueItalianoעבריתKurdîLatviešuLëtzebuergeschMagyarമലയാളംNederlands日本語NordfriiskNorsk:1
# bokmålOccitanPolskiPortuguêsRomânăРусскийSimple:1
# EnglishSlovenčinaSlovenščinaСрпски:1
# srpskiSrpskohrvatski:1
# српскохрватскиSuomiSvenskaไทยTürkçeУкраїнськаاردوTiếng:1
# Việt中文Edit:1
# linksArticleTalkEnglishReadEditView:1
# historyToolsToolsmove:1
# sidebarhideActionsReadEditView:1
# historyGeneralWhat:1
# links:1
# hereRelated:1
# fileSpecial:1
# pagesPermanent:1
# linkPage:1
# informationCite:1
# pageGet:1
# shortened:1
# URLDownload:1
# QR:1
# codeWikidata:1
# itemPrint/exportDownload:1
# PDFPrintable:1
# versionIn:1
# projectsWikimedia:1
# CommonsAppearancemove:1
# sidebarhideFrom:1
# Wikipedia,:1
# free:2
# encyclopedia.mw-parser-output:1
# .side-box{margin:4px:1
# 0;box-sizing:border-box;border:1px:1
# solid:3
# #aaa;font-size:88%;line-height:1.25em;background-color:var(--background-color-interactive-subtle,#f8f9fa);display:flow-root}.mw-parser-output:1
# .side-box-abovebelow,.mw-parser-output:1
# .side-box-text{padding:0.25em:1
# 0.9em}.mw-parser-output:1
# .side-box-image{padding:2px:1
# 0:2
# 2px:2
# 0.9em;text-align:center}.mw-parser-output:1
# .side-box-imageright{padding:2px:1
# 0.9em:1
# 0;text-align:center}@media(min-width:500px){.mw-parser-output:1
# .side-box-flex{display:flex;align-items:center}.mw-parser-output:1
# .side-box-text{flex:1;min-width:0}}@media(min-width:720px){.mw-parser-output:1
# .side-box{width:238px}.mw-parser-output:1
# .side-box-right{clear:right;float:right;margin-left:1em}.mw-parser-output:1
# .side-box-left{margin-right:1em}}@media:1
# print{body.ns-0:1
# .mw-parser-output:4
# .sistersitebox{display:none!important}}@media:1
# screen{html.skin-theme-clientpref-night:1
# .sistersitebox:2
# img[src*="Wiktionary-logo-en-v2.svg"]{background-color:white}}@media:1
# screen:1
# (prefers-color-scheme:dark){html.skin-theme-clientpref-os:1
# img[src*="Wiktionary-logo-en-v2.svg"]{background-color:white}}.mw-parser-output:1
# .plainlist:4
# ol,.mw-parser-output:1
# ul{line-height:inherit;list-style:none;margin:0;padding:0}.mw-parser-output:1
# ol:1
# li,.mw-parser-output:1
# ul:1
# li{margin-bottom:0}Look:1
# upTeslaorteslain:1
# Wiktionary,:1
# dictionary.Teslamost:1
# commonly:1
# refers:1
# to:Nikola:1
# Tesla(1856–1943),:1
# Serbian-American:1
# electrical:1
# engineer:1
# inventorTesla,:1
# Inc.,:2
# American:2
# electric:1
# vehicle:1
# clean:1
# energy:1
# company,:1
# formerly:1
# Motors,:1
# Inc.Tesla:1
# (unit)(symbol::1
# T),:1
# SI-derived:1
# unit:1
# magnetic:1
# flux:1
# densityTeslamay:1
# also:1
# refer:1
# to:@media:1
# (max-width:720px){body.skin-minerva:1
# .tocright{display:none}.mw-parser-output:1
# .tocright{width:100%!important}}@media:1
# (min-width:720px){.mw-parser-output:1
# .tocright{float:right;clear:right;width:auto;margin:0:1
# 0.5em:1
# 1em}.mw-parser-output:1
# .tocright-clear-left{clear:left}.mw-parser-output:1
# .tocright-clear-both{clear:both}.mw-parser-output:1
# .tocright-clear-none{clear:none}}Companies:1
# organizations[edit]Tesla:1
# a.s.,:1
# Czech:1
# electronics:1
# companyTesla:1
# Electric:1
# Light:1
# Manufacturing,:1
# former:2
# company:1
# Rahway,:1
# New:1
# Jersey,:1
# USMedia:1
# entertainment[edit]Tesla:1
# (band),:1
# hard:1
# rock:1
# band:1
# formed:1
# Sacramento,:1
# CaliforniaTesla:1
# –:1
# Lightning:1
# His:1
# Hand,:1
# 2003:1
# opera:1
# Constantine:1
# Koukias"Tesla",:1
# song:3
# 2013:1
# albumNanobotsby:1
# They:1
# Might:1
# Be:1
# Giants"Tesla":1
# (song),:1
# 2023:1
# Lil:1
# Yachty"Tesla",:1
# 2008:1
# Bosnian:1
# bandLetu:1
# štukeTesla(2016:1
# film),:2
# 2016:1
# film:2
# David:1
# GrubinTesla(2020:1
# 2020:1
# Michael:1
# AlmereydaPlaces[edit]Tesla,:1
# California,:3
# coal:1
# mining:1
# town:1
# Corral:1
# Hollow,:1
# USTesla,:1
# West:1
# Virginia,:1
# USTesla:2
# Fault,:1
# geological:1
# formation:1
# Diablo:1
# Range,:1
# River,:1
# RomaniaSpace[edit]2244:1
# Tesla,:3
# asteroid:1
# discovered:1
# 1952Tesla:1
# (crater),:1
# lunar:1
# craterScience:1
# technology[edit]Tesla:1
# (microarchitecture),:1
# microarchitecture:1
# developed:1
# NvidiaTeraelectronvolt:1
# Energy:1
# Superconducting:1
# Linear:2
# Accelerator,:1
# proposed:1
# particle:1
# collider,:1
# part:1
# International:1
# Collider:1
# projectNvidia:1
# brand:1
# GPGPU:1
# cards:1
# microarchitectureSee:1
# also[edit]List:1
# things:1
# named:1
# Nikola:2
# TeslaList:1
# patentsNikola:1
# (disambiguation)Nikola:1
# popular:1
# cultureAll:1
# titles:2
# containingTeslaAll:1
# beginning:1
# withTeslaTesler,:1
# surnameTSLAQ,:1
# loose:1
# collective:1
# critical:1
# Inc.Topics:1
# referred:1
# term.mw-parser-output:1
# .dmbox{display:flex;align-items:center;clear:both;margin:0.9em:1
# 1em;border-top:1px:1
# #ccc;border-bottom:1px:1
# #ccc;padding:0.25em:1
# 0.35em;font-style:italic}.mw-parser-output:1
# .dmbox>*{flex-shrink:0;margin:0:1
# 0.25em}.mw-parser-output:1
# .dmbox-body{flex-grow:1;flex-shrink:1;padding:0.1em:1
# 0}.mw-parser-output:1
# .dmbox-invalid-type{text-align:center}Thisdisambiguationpage:1
# lists:1
# articles:1
# associated:1
# titleTesla.If:1
# aninternal:1
# linkled:1
# here,:1
# may:2
# wish:1
# change:1
# link:1
# point:1
# directly:1
# intended:1
# article.Retrieved:1
# "https://en.wikipedia.org/w/index.php?title=Tesla&oldid=1241406863"Categories:Disambiguation:1
# pagesDisambiguation:1
# listsPlace:1
# pagesHidden:1
# categories:Short:1
# WikidataAll:1
# pagesAll:1
# pagesThis:1
# page:1
# last:1
# edited:1
# 21:1
# August:1
# 2024,:1
# 00:09(UTC).Text:1
# available:1
# theCreative:1
# Commons:1
# Attribution-ShareAlike:1
# License:1
# 4.0;:1
# additional:1
# terms:1
# apply.:1
# By:1
# using:1
# site,:1
# agree:1
# theTerms:1
# UseandPrivacy:1
# Policy.:1
# Wikipedia®:1
# registered:1
# trademark:1
# theWikimedia:1
# Foundation,:2
# non-profit:1
# organization.Privacy:1
# policyAbout:1
# WikipediaDisclaimersContact:1
# WikipediaCode:1
# ConductDevelopersStatisticsCookie:1
# statementMobile:1
# view(RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgHostname":"mw-web.eqiad.main-f7d55ccd6-2sb5p","wgBackendResponseTime":176,"wgPageParseReport":{"limitreport":{"cputime":"0.220","walltime":"0.321","ppvisitednodes":{"value":2564,"limit":1000000},"postexpandincludesize":{"value":6781,"limit":2097152},"templateargumentsize":{"value":1390,"limit":2097152},"expansiondepth":{"value":13,"limit":100},"expensivefunctioncount":{"value":1,"limit":500},"unstrip-depth":{"value":0,"limit":20},"unstrip-size":{"value":2688,"limit":5000000},"entityaccesscount":{"value":0,"limit":400},"timingprofile":["100.00%:1
# 262.236:1
# 1:9
# -total",":1
# 57.79%:1
# 151.550:1
# Template:Disambiguation",":1
# 29.96%:1
# 78.577:1
# Template:Wiktionary",":1
# 29.39%:1
# 77.068:1
# Template:Dmbox",":1
# 28.82%:1
# 75.575:1
# Template:Sister_project",":1
# 27.71%:1
# 72.663:1
# Template:Side_box",":1
# 19.63%:1
# 51.476:1
# 4:1
# Template:Main_other",":1
# 13.75%:1
# 36.051:1
# Template:Disambiguation_page_short_description",":1
# 12.97%:1
# 34.024:1
# Template:Short_description",":1
# 11.21%:1
# 29.404:1
# Template:Category_handler"]},"scribunto":{"limitreport-timeusage":{"value":"0.082","limit":"10.000"},"limitreport-memusage":{"value":1269149,"limit":52428800}},"cachereport":{"origin":"mw-web.eqiad.main-f7d55ccd6-676ds","timestamp":"20240907161943","ttl":2592000,"transientcontent":false}}});});{"@context":"https:\/\/schema.org","@type":"Article","name":"Tesla","url":"https:\/\/en.wikipedia.org\/wiki\/Tesla","sameAs":"http:\/\/www.wikidata.org\/entity\/Q765530","mainEntity":"http:\/\/www.wikidata.org\/entity\/Q765530","author":{"@type":"Organization","name":"Contributors:1
# Wikimedia:1
# projects"},"publisher":{"@type":"Organization","name":"Wikimedia:1
# Inc.","logo":{"@type":"ImageObject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png"}},"datePublished":"2004-08-27T20:47:13Z","dateModified":"2024-08-21T00:09:43Z","headline":"Wikimedia:1
# page"}:1
# <Axes: xlabel='Samples', ylabel='Counts'>
